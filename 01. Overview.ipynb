# %% [markdown]
# ![ilutracoes-menores.png](attachment:ilutracoes-menores.png)
#
# # Python for Data Analysis
#
# 1. Estrutura da linguagem
# 2. Importância da estrutura
# 3. Tipos de dados
# 4. Operações
#     1. Numéricas
#     2. Textuais
# 5. Tipos de dados e relações com as operações
# 6. Introdução a funções
# 7. Exercício 01
# 8. Explicação do Exercício 01
# 9. Desenvolvendo o pensamento computacional
#
# # Conceitos importantes
#
# 1. Formatos dos dados (Estruturados, não estruturados, semi-estruturados)
# 2. Fonte de dados
# 3. Pre-processamento de dados
# 4. Tratamento de dados
# 5. Agrupamento de dados
#
# ![agrupamento_regiao](images/agrupamento_estado.png)
# ![agrupamento_regiao](images/agrupamento_regiao.png)
#
#
# # Tratamento e manipulação de dados
#
# 1. Importando dados
# 2. Dados desestruturados e suas colunas
# 3. Conversão de dados nas tabelas (int, float, tratamento de data)
# 4. Valores ausentes
# 5. Pivotando tabelas
# 6. Filtrando registros
# 7. Concatenando tabelas
# 8. Relacionando tabelas
# 9. Criando chaves únicas
# 10. Exportando dados
#
# # Matematicamente falando
#
# 1. Medidas centrais e desvio padrão
# 2. Dados desbalanceados
# 3. ...
#
# # Visualização de dados
#
# 1. O que é uma visualização?
# 2. Tipos de tarefa e gráficos disponíveis
#
# # Exemplos
#
# ---

# %% [markdown]
# ## 1. Estrutura da linguagem

# %% [markdown]
# ## 2. Importância da estrutura

# %% [markdown]
# ## 3. Tipos de dados

# %% [markdown]
# ## 4. Operações

# %% [markdown]
# ### 4.1 Numéricas

# %% [markdown]
# ### 4.2 Textuais

# %% [markdown]
# ## 5. Tipos de dados e relações com as operações

# %% [markdown]
# ## 6. Introdução a funções

# %% [markdown]
# ## 7. Exercício 01: Renda
#
# Fonte: https://pt.tradingeconomics.com/country-list/gdp-per-capita

# %% [markdown]
# ## 8. Explicação do Exercício 01
